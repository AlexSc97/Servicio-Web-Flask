# %% [markdown]
# # Servicio web usando Flask para prediccion de probabilidad de desarrollar diabetes
# - Para este proyecto utilizaré un modelo xgboost previamente entrenado y optimizado utilizando optuna, en el que anteriormente he trabajado y se encuentra en mi propio repositorio: https://github.com/AlexSc97/machine-learning-boosting.git
# - El data set que se utilizó
# - Este modelo tiene las siguientes metricas de desempeño, lo cual me interesa AUC que es la capacidad de separar oh clasificar los grupos que desarrollaran diabetes o no.
# - Tiene una precision del 82% para detectar la probabilidad de desarrollar diabetes.

# %% [markdown]
# ![image.png](attachment:53d237d4-75bb-4ca7-a360-c1d22fb74554.png)

# %% [markdown]
# La imagen fue obtenida de mi repositorio donde entrene varios modelos de arboles para lograr una clasificacion binaria y detectar si una persona es propensa a desarrollar diabetes
# - Debido a su rendimiento, el modelo optimizado XGBoost_Optimized sera el que se utilizará para crear el servicio web flask.

# %%
import pickle

# Ruta donde almacene el modelo
model_path = '../models/modelo_xg_optimizado.pkl'

# Abrir el archivo en modo de lectura binaria ('rb') y cargar el modelo
with open(model_path, 'rb') as file:
    model = pickle.load(file)

# Ahora la variable model contiene tu modelo entrenado XgBoost_optimizado.
print("Modelo cargado exitosamente.")
print(model)
# Out:
# Modelo cargado exitosamente.
# ...
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_17044\1370489006.py:8: UserWarning: [05:42:47] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\data\../common/error_msg.h:83: If you are loading a serialized model (like pickle in Python, RDS in R) or
# configuration generated by an older version of XGBoost, please export the model by calling
# `Booster.save_model` from that version first, then load it back in current version. See:
#
#     https://xgboost.readthedocs.io/en/stable/tutorials/saving_model.html
#
# for more details about differences between saving model and serializing.
#
#   model = pickle.load(file)
